# %%
# Library yang perlu diimport
import pandas as pd
import requests
from bs4 import BeautifulSoup
import csv

# %%
root = "https://quotes.toscrape.com/"
link = "https://quotes.toscrape.com/page/1/"
def quotes(link):
    global root

    session = requests.Session()
    headers = {'User-Agent': 'Mozilla/5.0'}
    response = session.get(link, headers=headers)
    soup = BeautifulSoup(response.content, 'html.parser')

#     print(soup)

    news_results = soup.find_all('div', attrs={'class': 'quote'})
#     print(news_results)

    data = []

    for item in news_results:
        quote = item.find('div', attrs={'class': 'text'}).get_text()
        author = item.find('div', attrs={'class': 'author'}).get_text()
        tags = item.find('div', attrs={'class': 'tag'}).get_text()
#         print(judul)


        data.append({'Quote': quote, 'Author': author, 'Tags': tags})

    next_page = soup.find('a', attrs={'href': '/page/2/'})

    if next_page:
        next_page_url = root + next_page['href']
        data.extend(news(next_page_url))

    return data

data = quotes(link)

# Save the data to a CSV file
csv_file = 'Quotes.csv'
csv_columns = ['Quote', 'Author', 'Tags']
with open(csv_file, 'w', newline='', encoding='utf-8') as file:
    writer = csv.DictWriter(file, fieldnames=csv_columns)
    writer.writeheader()
    writer.writerows(data)

print("Data saved to", csv_file)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-5d18ab59d221> in <cell line: 35>()
#      33     return data
#      34
# ---> 35 data = quotes(link)
#      36
#      37 # Save the data to a CSV file
#
# <ipython-input-7-5d18ab59d221> in quotes(link)
#      17
#      18     for item in news_results:
# ---> 19         quote = item.find('div', attrs={'itemprop': 'text'}).get_text()
#      20         author = item.find('div', attrs={'class': 'author'}).get_text()
#      21         tags = item.find('div', attrs={'class': 'tag'}).get_text()
#
# AttributeError: 'NoneType' object has no attribute 'get_text'
