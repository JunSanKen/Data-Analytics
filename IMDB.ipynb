# %% [markdown]
# Note : Saya sudah mencoba untuk menggunakan template dari yang Bapak sediakan. Namun, saya tidak mendapatkan hasil yang sesuai dengan yang diharapkan, sehingga saya mengganti website beberapa kali namun juga tidak mendapatkan hasil yang seharusnya. Saya mencoba menggunakan template dari internet, namun juga tidak mendapatkan hasil yang sesuai. Mohon bimbingan dan pengertiannya, Pak. Terima Kasih

# %%
# Library yang perlu diimport
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
# URL website yang mau di scrap
url = "https://www.imdb.com/chart/top"

# Mengirim HTTP GET
response = requests.get(url)

# Parse HTML
soup = BeautifulSoup(response.content, 'html.parser')

# Mengesktrak data yang di perlukan
movies = []
for row in soup.select('ipc-title-link-wrapper'):
  title = row.find('h3', attrs={'class':'ipc-title__text'}).get_text()
  year = row.find('span', attrs={'class':'sc-43986a27-8 jHYIIK cli-title-metadata-item'}).get_text()
  rating = row.find('span', attrs={'class':'ipc-rating-star ipc-rating-star--base ipc-rating-star--imdb sc-9ab53865-1 iXEijC ratingGroup--imdb-rating'}).get_text()
  movies.append([title, year, rating])

# Menyimpan informasi yang ada
df = pd.DataFrame(movies, columns=['Title', 'Year', 'Rating'])

# Menambahkan delay
time.sleep(1)

# %%
df.to_csv('top-rated-movies.csv', index=False)

# %%
df.head(10000)
# Out:
# Empty DataFrame
# Columns: [Title, Year, Rating]
# Index: []
