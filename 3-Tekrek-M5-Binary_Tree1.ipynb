# %%
pip install binarytree
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting binarytree
#   Downloading binarytree-6.5.1-py3-none-any.whl (18 kB)
# Requirement already satisfied: setuptools>=60.8.2 in /usr/local/lib/python3.9/dist-packages (from binarytree) (67.6.1)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.9/dist-packages (from binarytree) (0.20.1)
# Collecting setuptools-scm[toml]>=5.0.1
#   Downloading setuptools_scm-7.1.0-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from setuptools-scm[toml]>=5.0.1->binarytree) (4.5.0)
# Requirement already satisfied: tomli>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from setuptools-scm[toml]>=5.0.1->binarytree) (2.0.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from setuptools-scm[toml]>=5.0.1->binarytree) (23.0)
# Installing collected packages: setuptools-scm, binarytree
# Successfully installed binarytree-6.5.1 setuptools-scm-7.1.0

# %%
from binarytree import build

# %%
# List of nodes
nodes =[3, 6, 8, 2, 11, None, 13]

# %%
binary_tree = build(nodes)
print('Binary tree from list :\n',
      binary_tree)
# Out:
# Binary tree from list :
#
#     ___3
#    /    \
#   6      8
#  / \      \
# 2   11     13

# %%
# Getting list of nodes from
# binarytree
print('\nList from binary tree :',
      binary_tree.values)
# Out:
# List from binary tree : [3, 6, 8, 2, 11, None, 13]
