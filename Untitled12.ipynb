# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def scrape_kompas_news():
    url = 'https://www.kompas.com/'
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # Temukan artikel berita di halaman utama
        articles = soup.find_all('article')

        # Ekstrak informasi relevan (judul dan tautan) dari setiap artikel
        news_data = []
        for article in articles:
            title = article.find('h4', class_='media__title').get_text(strip=True)
            link = article.find('a', class_='media__link')['href']
            news_data.append({'Title': title, 'Link': link})

        return news_data
    else:
        print(f"Gagal mengambil data. Kode status: {response.status_code}")
        return None

def save_to_csv(data, filename='kompas_news.csv'):
    df = pd.DataFrame(data)
    df.to_csv(filename, index=False)
    print(f"Data disimpan ke {filename}")

# Script utama
if __name__ == "__main__":
    # Ekstrak data dari halaman utama Kompas
    kompas_news_data = scrape_kompas_news()

    if kompas_news_data:
        # Simpan data ke file CSV
        save_to_csv(kompas_news_data)
