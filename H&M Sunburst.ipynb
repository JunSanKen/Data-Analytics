# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
article = pd.read_csv("/content/drive/MyDrive/Sunburst H&M/articles.csv")
customer = pd.read_csv("/content/drive/MyDrive/Sunburst H&M/customers.csv")
sample_submission = pd.read_csv("/content/drive/MyDrive/Sunburst H&M/sample_submission.csv")
transaction_train = pd.read_csv("/content/drive/MyDrive/Sunburst H&M/transactions_train.csv")

# %%
article.shape
# Out:
# (105542, 25)

# %%
customer.shape
# Out:
# (1371980, 7)

# %%
sample_submission.shape
# Out:
# (1371980, 2)

# %%
transaction_train.shape
# Out:
# (31788324, 5)

# %%
article.head()
# Out:
#    article_id  product_code          prod_name  product_type_no  \
# 0   108775015        108775          Strap top              253
# 1   108775044        108775          Strap top              253
# 2   108775051        108775      Strap top (1)              253
# 3   110065001        110065  OP T-shirt (Idro)              306
# 4   110065002        110065  OP T-shirt (Idro)              306
#
#   product_type_name  product_group_name  graphical_appearance_no  \
# 0          Vest top  Garment Upper body                  1010016
# 1          Vest top  Garment Upper body                  1010016
# 2          Vest top  Garment Upper body                  1010017
# 3               Bra           Underwear                  1010016
# 4               Bra           Underwear                  1010016
#
#   graphical_appearance_name  colour_group_code colour_group_name  ...  \
# 0                     Solid                  9             Black  ...
# 1                     Solid                 10             White  ...
# 2                    Stripe                 11         Off White  ...
# 3                     Solid                  9             Black  ...
# 4                     Solid                 10             White  ...
#
#    department_name index_code        index_name index_group_no  \
# 0     Jersey Basic          A        Ladieswear              1
# 1     Jersey Basic          A        Ladieswear              1
# 2     Jersey Basic          A        Ladieswear              1
# 3   Clean Lingerie          B  Lingeries/Tights              1
# 4   Clean Lingerie          B  Lingeries/Tights              1
#
#    index_group_name section_no            section_name garment_group_no  \
# 0        Ladieswear         16  Womens Everyday Basics             1002
# 1        Ladieswear         16  Womens Everyday Basics             1002
# 2        Ladieswear         16  Womens Everyday Basics             1002
# 3        Ladieswear         61         Womens Lingerie             1017
# 4        Ladieswear         61         Womens Lingerie             1017
#
#    garment_group_name                                        detail_desc
# 0        Jersey Basic            Jersey top with narrow shoulder straps.
# 1        Jersey Basic            Jersey top with narrow shoulder straps.
# 2        Jersey Basic            Jersey top with narrow shoulder straps.
# 3   Under-, Nightwear  Microfibre T-shirt bra with underwired, moulde...
# 4   Under-, Nightwear  Microfibre T-shirt bra with underwired, moulde...
#
# [5 rows x 25 columns]

# %%
customer.head()
# Out:
#                                          customer_id   FN  Active  \
# 0  00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...  NaN     NaN
# 1  0000423b00ade91418cceaf3b26c6af3dd342b51fd051e...  NaN     NaN
# 2  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...  NaN     NaN
# 3  00005ca1c9ed5f5146b52ac8639a40ca9d57aeff4d1bd2...  NaN     NaN
# 4  00006413d8573cd20ed7128e53b7b13819fe5cfc2d801f...  1.0     1.0
#
#   club_member_status fashion_news_frequency   age  \
# 0             ACTIVE                   NONE  49.0
# 1             ACTIVE                   NONE  25.0
# 2             ACTIVE                   NONE  24.0
# 3             ACTIVE                   NONE  54.0
# 4             ACTIVE              Regularly  52.0
#
#                                          postal_code
# 0  52043ee2162cf5aa7ee79974281641c6f11a68d276429a...
# 1  2973abc54daa8a5f8ccfe9362140c63247c5eee03f1d93...
# 2  64f17e6a330a85798e4998f62d0930d14db8db1c054af6...
# 3  5d36574f52495e81f019b680c843c443bd343d5ca5b1c2...
# 4  25fa5ddee9aac01b35208d01736e57942317d756b32ddd...

# %%
sample_submission.head()
# Out:
#                                          customer_id  \
# 0  00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...
# 1  0000423b00ade91418cceaf3b26c6af3dd342b51fd051e...
# 2  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...
# 3  00005ca1c9ed5f5146b52ac8639a40ca9d57aeff4d1bd2...
# 4  00006413d8573cd20ed7128e53b7b13819fe5cfc2d801f...
#
#                                           prediction
# 0  0706016001 0706016002 0372860001 0610776002 07...
# 1  0706016001 0706016002 0372860001 0610776002 07...
# 2  0706016001 0706016002 0372860001 0610776002 07...
# 3  0706016001 0706016002 0372860001 0610776002 07...
# 4  0706016001 0706016002 0372860001 0610776002 07...

# %%
transaction_train
# Out:
#                t_dat                                        customer_id  \
# 0         2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...
# 1         2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...
# 2         2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...
# 3         2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...
# 4         2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...
# ...              ...                                                ...
# 31788319  2020-09-22  fff2282977442e327b45d8c89afde25617d00124d0f999...
# 31788320  2020-09-22  fff2282977442e327b45d8c89afde25617d00124d0f999...
# 31788321  2020-09-22  fff380805474b287b05cb2a7507b9a013482f7dd0bce0e...
# 31788322  2020-09-22  fff4d3a8b1f3b60af93e78c30a7cb4cf75edaf2590d3e5...
# 31788323  2020-09-22  fffef3b6b73545df065b521e19f64bf6fe93bfd450ab20...
#
#           article_id     price  sales_channel_id
# 0          663713001  0.050831                 2
# 1          541518023  0.030492                 2
# 2          505221004  0.015237                 2
# 3          685687003  0.016932                 2
# 4          685687004  0.016932                 2
# ...              ...       ...               ...
# 31788319   929511001  0.059305                 2
# 31788320   891322004  0.042356                 2
# 31788321   918325001  0.043203                 1
# 31788322   833459002  0.006763                 1
# 31788323   898573003  0.033881                 2
#
# [31788324 rows x 5 columns]

# %%
import plotly.express as px
label = article.index_group_name.unique()
count = article.index_group_name.value_counts()
fig = px.pie(article, values=count, names=label,color_discrete_sequence=px.colors.sequential.Purpor)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="901831cf-81e6-4ea6-a852-f6bf0b9f38c9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("901831cf-81e6-4ea6-a852-f6bf0b9f38c9")) {                    Plotly.newPlot(                        "901831cf-81e6-4ea6-a852-f6bf0b9f38c9",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}<br>value=%{value}<extra></extra>","labels":["Ladieswear","Baby/Children","Menswear","Sport","Divided"],"legendgroup":"","name":"","showlegend":true,"values":[39737,34711,15149,12553,3392],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"m ...

# %%
name = article.garment_group_name.unique()
sizes = article.garment_group_name.value_counts()
fig = px.bar(article, y=sizes, x=name, color = name,color_discrete_sequence=px.colors.sequential.Plotly3
            )
fig.update_layout(
    title="Count of Garment Group Name",
    xaxis_title="Garment Group Name",
    yaxis_title="Count"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="a5425b8d-74bd-47b1-8ffa-037d56a07244" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a5425b8d-74bd-47b1-8ffa-037d56a07244")) {                    Plotly.newPlot(                        "a5425b8d-74bd-47b1-8ffa-037d56a07244",                        [{"alignmentgroup":"True","hovertemplate":"color=Jersey Basic<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Jersey Basic","marker":{"color":"#0508b8","pattern":{"shape":""}},"name":"Jersey Basic","offsetgroup":"Jersey Basic","orientation":"v","showlegend":true,"textposition":"auto","x":["Jersey Basic"],"xaxis":"x","y":[21445],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Under-, Nightwear<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Under-, Nightwear","marker":{"color":"#1910d8","pattern":{"shape":""}},"name":"Under-, Nightwear","offsetgroup":"Under-, Nightwear","orientation":"v","showlegend":true,"textposition":"auto","x":["Under-, Nightwear"],"xaxis":"x","y":[11519],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Socks and Tights<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Socks and Tights","marker":{"color":"#3c19f0","pattern":{"shape":""}},"name":"Socks and Tights","offsetgroup":"Socks and Tights","orientation":"v","showlegend":true,"textposition":"auto","x":["Socks and Tights"],"xaxis":"x","y":[8126],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Jersey Fancy<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Jersey Fancy","marker":{"color":"#6b1cfb","pattern":{"shape":""}},"name":"Jersey Fancy","offsetgroup":"Jersey Fancy","orientation":"v","showlegend":true,"textposition":"auto","x":["Jersey Fancy"],"xaxis":"x","y":[7490],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Accessories<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Accessories","marker":{"color":"#981cfd","pattern":{"shape":""}},"name":"Accessories","offsetgroup":"Accessories","orientation":"v","showlegend":true,"textposition":"auto","x":["Accessories"],"xaxis":"x","y":[7441],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Trousers Denim<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Trousers Denim","marker":{"color":"#bf1cfd","pattern":{"shape":""}},"name":"Trousers Denim","offsetgroup":"Trousers Denim","orientation":"v","showlegend":true,"textposition":"auto","x":["Trousers Denim"],"xaxis":"x","y":[6727],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Outdoor<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Outdoor","marker":{"color":"#dd2bfd","pattern":{"shape":""}},"name":"Outdoor","offsetgroup":"Outdoor","orientation":"v","showlegend":true,"textposition":"auto","x":["Outdoor"],"xaxis":"x","y":[5838],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Shoes<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Shoes","marker":{"color":"#f246fe","pattern":{"shape":""}},"name":"Shoes","offsetgroup":"Shoes","orientation":"v","showlegend":true,"textposition":"auto","x":["Shoes"],"xaxis":"x","y":[5145],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Swimwear<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Swimwear","marker":{"color":"#fc67fd","pattern":{"shape":""}},"name":"Swimwear","offsetgroup":"Swimwear","orientation":"v","showlegend":true,"textposition":"auto","x":["Swimwear"],"xaxis":"x","y":[4874],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Knitwear<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Knitwear","marker":{"color":"#fe88fc","pattern":{"shape":""}},"name":"Knitwear","offsetgroup":"Knitwear","orientation":"v","showlegend":true,"textposition":"au ...

# %%
name = article.index_name.unique()
sizes = article.index_name.value_counts()
fig = px.bar(article, y=sizes, x=name, color = name,color_discrete_sequence=px.colors.diverging.Picnic)
fig.update_layout(
    title="Count of Index name",
    xaxis_title="index_name",
    yaxis_title="Count"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="10276d22-b2e4-48d5-87cd-44f7732ca1a8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("10276d22-b2e4-48d5-87cd-44f7732ca1a8")) {                    Plotly.newPlot(                        "10276d22-b2e4-48d5-87cd-44f7732ca1a8",                        [{"alignmentgroup":"True","hovertemplate":"color=Ladieswear<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Ladieswear","marker":{"color":"rgb(0,0,255)","pattern":{"shape":""}},"name":"Ladieswear","offsetgroup":"Ladieswear","orientation":"v","showlegend":true,"textposition":"auto","x":["Ladieswear"],"xaxis":"x","y":[26001],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Lingeries/Tights<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Lingeries/Tights","marker":{"color":"rgb(51,153,255)","pattern":{"shape":""}},"name":"Lingeries/Tights","offsetgroup":"Lingeries/Tights","orientation":"v","showlegend":true,"textposition":"auto","x":["Lingeries/Tights"],"xaxis":"x","y":[15149],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Baby Sizes 50-98<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Baby Sizes 50-98","marker":{"color":"rgb(102,204,255)","pattern":{"shape":""}},"name":"Baby Sizes 50-98","offsetgroup":"Baby Sizes 50-98","orientation":"v","showlegend":true,"textposition":"auto","x":["Baby Sizes 50-98"],"xaxis":"x","y":[12553],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Menswear<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Menswear","marker":{"color":"rgb(153,204,255)","pattern":{"shape":""}},"name":"Menswear","offsetgroup":"Menswear","orientation":"v","showlegend":true,"textposition":"auto","x":["Menswear"],"xaxis":"x","y":[12007],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Ladies Accessories<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Ladies Accessories","marker":{"color":"rgb(204,204,255)","pattern":{"shape":""}},"name":"Ladies Accessories","offsetgroup":"Ladies Accessories","orientation":"v","showlegend":true,"textposition":"auto","x":["Ladies Accessories"],"xaxis":"x","y":[9214],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Sport<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Sport","marker":{"color":"rgb(255,255,255)","pattern":{"shape":""}},"name":"Sport","offsetgroup":"Sport","orientation":"v","showlegend":true,"textposition":"auto","x":["Sport"],"xaxis":"x","y":[8875],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Children Sizes 92-140<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Children Sizes 92-140","marker":{"color":"rgb(255,204,255)","pattern":{"shape":""}},"name":"Children Sizes 92-140","offsetgroup":"Children Sizes 92-140","orientation":"v","showlegend":true,"textposition":"auto","x":["Children Sizes 92-140"],"xaxis":"x","y":[6961],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Divided<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Divided","marker":{"color":"rgb(255,153,255)","pattern":{"shape":""}},"name":"Divided","offsetgroup":"Divided","orientation":"v","showlegend":true,"textposition":"auto","x":["Divided"],"xaxis":"x","y":[6775],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Children Sizes 134-170<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Children Sizes 134-170","marker":{"color":"rgb(255,102,204)","pattern":{"shape":""}},"name":"Children Sizes 134-170","offsetgroup":"Children Sizes 134-170","orientation":"v","showlegend":true,"textposition":"auto","x":["Children Sizes 134-170"],"xaxis":"x","y":[4615],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Children Accessories, Swimwear<br>x= ...

# %%
fig = px.sunburst(article, path=['index_group_name', 'index_name', 'garment_group_name'],width=800,
    height=800,color_discrete_sequence=px.colors.cyclical.Edge)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="3a9dff22-9417-4b92-b0d4-e920f35234d6" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3a9dff22-9417-4b92-b0d4-e920f35234d6")) {                    Plotly.newPlot(                        "3a9dff22-9417-4b92-b0d4-e920f35234d6",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["Baby/Children/Baby Sizes 50-98/Accessories","Baby/Children/Children Accessories, Swimwear/Accessories","Divided/Divided/Accessories","Ladieswear/Ladies Accessories/Accessories","Ladieswear/Ladieswear/Accessories","Menswear/Menswear/Accessories","Sport/Sport/Accessories","Divided/Divided/Blouses","Ladieswear/Ladieswear/Blouses","Ladieswear/Ladieswear/Dressed","Menswear/Menswear/Dressed","Divided/Divided/Dresses Ladies","Ladieswear/Ladieswear/Dresses Ladies","Baby/Children/Children Sizes 134-170/Dresses/Skirts girls","Baby/Children/Children Sizes 92-140/Dresses/Skirts girls","Baby/Children/Baby Sizes 50-98/Jersey Basic","Baby/Children/Children Sizes 134-170/Jersey Basic","Baby/Children/Children Sizes 92-140/Jersey Basic","Divided/Divided/Jersey Basic","Ladie