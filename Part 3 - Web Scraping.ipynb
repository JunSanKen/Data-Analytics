# %%
# Library yang perlu diimport
import pandas as pd
import requests
from bs4 import BeautifulSoup
import csv

# %%
root = "https://duckduckgo.com"
link = "https://duckduckgo.com/?t=h_&q=information+technology&ia=web"
def news(link):
    global root

    session = requests.Session()
    headers = {'User-Agent': 'Mozilla/5.0'}
    response = session.get(link, headers=headers)
    soup = BeautifulSoup(response.content, 'html.parser')

  print(soup)

    news_results = soup.find_all('div', attrs={'class': 'Gx5Zad fP1Qef xpd EtOod pkphOe'})
#     print(news_results)

    data = []

    for item in news_results:
        judul = item.find('div', attrs={'class': 'BNeawe vvjwJb AP7Wnd'}).get_text()
        penerbit = item.find('div', attrs={'class': 'BNeawe UPmit AP7Wnd lRVwie'}).get_text()
        deskripsi = item.find('div', attrs={'class': 'BNeawe s3v9rd AP7Wnd'}).get_text()
        waktu = deskripsi.split(".")[-1]
        raw_link = (item.find('a', href=True)['href'])
        link = (raw_link.split("/url?q=")[1]).split('&sa=U&')[0]
#         print(judul)


        data.append({'Judul': judul, 'Penerbit': penerbit, 'Waktu': waktu, 'Link' : link})

    next_page = soup.find('a', attrs={'aria-label': 'Halaman berikutnya'})

    if next_page:
        next_page_url = root + next_page['href']
        data.extend(news(next_page_url))

    return data

data = news(link)

# Save the data to a CSV file
csv_file = 'berita_ds.csv'
csv_columns = ['Judul', 'Penerbit', 'Waktu', 'Link']
with open(csv_file, 'w', newline='', encoding='utf-8') as file:
    writer = csv.DictWriter(file, fieldnames=csv_columns)
    writer.writeheader()
    writer.writerows(data)

print("Data saved to", csv_file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-70f4cd22bf0e> in <cell line: 11>()
#       9     soup = BeautifulSoup(response.content, 'html.parser')
#      10
# ---> 11 print(soup)
#      12
#      13
#
# NameError: name 'soup' is not defined

# %%
root = "https://duckduckgo.com"
link = "https://duckduckgo.com/?t=h_&q=information+technology&ia=web"
def news(link):
    global root

    session = requests.Session()
    headers = {'User-Agent': 'Mozilla/5.0'}
    response = session.get(link, headers=headers)
    soup = BeautifulSoup(response.content, 'html.parser')

  print(soup)

    news_results = soup.find_all('div', attrs={'class': 'Gx5Zad fP1Qef xpd EtOod pkphOe'})
#     print(news_results)

    data = []

    for item in news_results:
        judul = item.find('div', attrs={'class': 'BNeawe vvjwJb AP7Wnd'}).get_text()
        penerbit = item.find('div', attrs={'class': 'BNeawe UPmit AP7Wnd lRVwie'}).get_text()
        deskripsi = item.find('div', attrs={'class': 'BNeawe s3v9rd AP7Wnd'}).get_text()
        waktu = deskripsi.split(".")[-1]
        raw_link = (item.find('a', href=True)['href'])
        link = (raw_link.split("/url?q=")[1]).split('&sa=U&')[0]
#         print(judul)


        data.append({'Judul': judul, 'Penerbit': penerbit, 'Waktu': waktu, 'Link' : link})

    next_page = soup.find('a', attrs={'aria-label': 'Halaman berikutnya'})

    if next_page:
        next_page_url = root + next_page['href']
        data.extend(news(next_page_url))

    return data

data = news(link)

# Save the data to a CSV file
csv_file = 'berita_ds.csv'
csv_columns = ['Judul', 'Penerbit', 'Waktu', 'Link']
with open(csv_file, 'w', newline='', encoding='utf-8') as file:
    writer = csv.DictWriter(file, fieldnames=csv_columns)
    writer.writeheader()
    writer.writerows(data)

print("Data saved to", csv_file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-70f4cd22bf0e> in <cell line: 11>()
#       9     soup = BeautifulSoup(response.content, 'html.parser')
#      10
# ---> 11 print(soup)
#      12
#      13
#
# NameError: name 'soup' is not defined

# %%
df = pd.read_csv("berita_ds.csv")

# %%
df.head(10000)
# Out:
#                                                  Judul        Penerbit  \
# 0    Menanti Debat Capres Kedua untuk Pilpres 2024?...        Nasional
# 1    7 Survei Terbaru Capres-Cawapres 2024, Siapa U...  CNBC Indonesia
# 2    KPU Ingatkan Kandidat Pilpres 2024 untuk Patuh...       Kompas.id
# 3    Debat Cawapres Panas, Ini 6 Survei Terbaru Pil...  CNBC Indonesia
# 4    Survei Pilpres 2024 Usai Debat Capres-Cawapres...      Kompas.com
# ..                                                 ...             ...
# 295  KPU: Tema debat Pilpres 2024 tidak jauh dari R...  Antaranews.com
# 296  Dua pasang calon presiden-calon wakil presiden...      Benar News
# 297  Pendaftaran Ditutup, Kapan Penetapan Capres-Ca...      KOMPAS.com
# 298                  Ini Jadwal & Tahapan Pilpres 2024        Metro TV
# 299  Elektabilitas ke-3 Capres dari Berbagai Survei...    Liputan6.com
#
#             Waktu                                               Link
# 0      4 jam lalu  https://nasional.tempo.co/read/1813529/menanti...
# 1     1 hari lalu  https://www.cnbcindonesia.com/news/20231224024...
# 2     1 hari lalu  https://www.kompas.id/baca/polhuk/2023/12/23/k...
# 3     2 hari lalu  https://www.cnbcindonesia.com/news/20231223083...
# 4     1 hari lalu  https://www.kompas.com/tren/read/2023/12/24/19...
# ..            ...                                                ...
# 295  1 bulan lalu  https://www.antaranews.com/berita/3841182/kpu-...
# 296  2 bulan lalu  https://www.benarnews.org/indonesian/berita/du...
# 297  1 bulan lalu  https://nasional.kompas.com/read/2023/10/26/14...
# 298  3 bulan lalu  https://www.metrotvnews.com/play/bVDCOxZX-ini-...
# 299  1 bulan lalu  https://www.liputan6.com/pemilu/read/5459196/e...
#
# [300 rows x 4 columns]
